# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import random
import csv
import pprint
import openweathermapy.core as owm

# Import API key
api_key = "f82e51275cfca026c27fe0b31e80d5fa"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs, cities, and other variables
cities = []
lat_lngs = []
temp = []
humidity = []
cloudiness = []
wind_speed = []
lat = []
lon = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %% [markdown]
# ### Perform API Calls

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

cities_df = pd.DataFrame()
cities_df['City'] = cities

for index, row in cities_df.iterrows():
    try:
        city_name = row['City']
        print(city_name)
        print(index)
        response = requests.get(query_url + city_name).json()
        temp.append(response['main']['temp'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        print(f"Processing record | {city_name}")
        print(query_url + city_name)
    except KeyError:
        print(f"Weather for {city_name} not found.")
        temp.append("Null")
        lat.append("Null")
        lon.append("Null")
        humidity.append("Null")
        cloudiness.append("Null")
        wind_speed.append("Null")
        continue
# Out:
# sao filipe
# 0
# Processing record | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=sao filipe
# rikitea
# 1
# Processing record | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=rikitea
# carmen
# 2
# Processing record | carmen
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=carmen
# hasaki
# 3
# Processing record | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=hasaki
# sikasso
# 4
# Processing record | sikasso
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=sikasso
# soyo
# 5
# Processing record | soyo
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=soyo
# itaituba
# 6
# Processing record | itaituba
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=itaituba
# kibaya
# 7
# Processing record | kibaya
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kibaya
# pastavy
# 8
# Processing record | pastavy
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=pastavy
# pangnirtung
# 9
# Processing record | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=pangnirtung
# mataura
# 10
# Processing record | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=mataura
# athieme
# 11
# Weather for athieme not found.
# kodiak
# 12
# Processing record | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kodiak
# erdenet
# 13
# Processing record | erdenet
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=erdenet
# nouadhibou
# 14
# Processing record | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=nouadhibou
# vao
# 15
# Processing record | vao
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=vao
# hobart
# 16
# Processing record | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=hobart
# barrow
# 17
# Processing record | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=barrow
# ekhabi
# 18
# Processing record | ekhabi
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ekhabi
# camalu
# 19
# Processing record | camalu
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=camalu
# iwaki
# 20
# Processing record | iwaki
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=iwaki
# saskylakh
# 21
# Processing record | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=saskylakh
# punta arenas
# 22
# Processing record | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=punta arenas
# hilo
# 23
# Processing record | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=hilo
# dingle
# 24
# Processing record | dingle
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=dingle
# nueve de julio
# 25
# Processing record | nueve de julio
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=nueve de julio
# ludvika
# 26
# Processing record | ludvika
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ludvika
# chokurdakh
# 27
# Processing record | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=chokurdakh
# rio gallegos
# 28
# Processing record | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=rio gallegos
# shibetsu
# 29
# Processing record | shibetsu
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=shibetsu
# beringovskiy
# 30
# Processing record | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=beringovskiy
# belushya guba
# 31
# Weather for belushya guba not found.
# busselton
# 32
# Processing record | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=busselton
# westport
# 33
# Processing record | westport
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=westport
# ushuaia
# 34
# Processing record | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ushuaia
# khatanga
# 35
# Processing record | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=khatanga
# ostrovnoy
# 36
# Processing record | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ostrovnoy
# victoria
# 37
# Processing record | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=victoria
# maunabo
# 38
# Processing record | maunabo
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=maunabo
# gasa
# 39
# Processing record | gasa
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=gasa
# vestmanna
# 40
# Processing record | vestmanna
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=vestmanna
# college
# 41
# Processing record | college
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=college
# port alfred
# 42
# Processing record | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=port alfred
# la romana
# 43
# Processing record | la romana
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=la romana
# albany
# 44
# Processing record | albany
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=albany
# jamestown
# 45
# Processing record | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=jamestown
# aklavik
# 46
# Processing record | aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=aklavik
# high level
# 47
# Processing record | high level
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=high level
# vaini
# 48
# Processing record | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=vaini
# rio grande
# 49
# Processing record | rio grande
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=rio grande
# najran
# 50
# Processing record | najran
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=najran
# ankazoabo
# 51
# Processing record | ankazoabo
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ankazoabo
# tumannyy
# 52
# Weather for tumannyy not found.
# mpophomeni
# 53
# Processing record | mpophomeni
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=mpophomeni
# kununurra
# 54
# Processing record | kununurra
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kununurra
# port elizabeth
# 55
# Processing record | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=port elizabeth
# sorong
# 56
# Processing record | sorong
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=sorong
# butaritari
# 57
# Processing record | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=butaritari
# lompoc
# 58
# Processing record | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=lompoc
# prieska
# 59
# Processing record | prieska
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=prieska
# saryshagan
# 60
# Weather for saryshagan not found.
# zabol
# 61
# Processing record | zabol
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=zabol
# hermanus
# 62
# Processing record | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=hermanus
# lere
# 63
# Processing record | lere
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=lere
# mar del plata
# 64
# Processing record | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=mar del plata
# alta floresta
# 65
# Processing record | alta floresta
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=alta floresta
# dauphin
# 66
# Processing record | dauphin
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=dauphin
# baillif
# 67
# Processing record | baillif
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=baillif
# taolanaro
# 68
# Weather for taolanaro not found.
# grand river south east
# 69
# Weather for grand river south east not found.
# puerto ayora
# 70
# Processing record | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=puerto ayora
# ryotsu
# 71
# Processing record | ryotsu
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ryotsu
# new norfolk
# 72
# Processing record | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=new norfolk
# atuona
# 73
# Processing record | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=atuona
# ola
# 74
# Processing record | ola
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ola
# sakakah
# 75
# Weather for sakakah not found.
# carnarvon
# 76
# Processing record | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=carnarvon
# goderich
# 77
# Processing record | goderich
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=goderich
# abu zabad
# 78
# Processing record | abu zabad
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=abu zabad
# meyungs
# 79
# Weather for meyungs not found.
# lac du bonnet
# 80
# Processing record | lac du bonnet
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=lac du bonnet
# springbok
# 81
# Processing record | springbok
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=springbok
# karpogory
# 82
# Processing record | karpogory
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=karpogory
# mount isa
# 83
# Processing record | mount isa
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=mount isa
# auki
# 84
# Processing record | auki
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=auki
# amderma
# 85
# Weather for amderma not found.
# praia da vitoria
# 86
# Processing record | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=praia da vitoria
# shubarshi
# 87
# Processing record | shubarshi
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=shubarshi
# norman wells
# 88
# Processing record | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=norman wells
# dunedin
# 89
# Processing record | dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=dunedin
# taltal
# 90
# Processing record | taltal
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=taltal
# sirjan
# 91
# Processing record | sirjan
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=sirjan
# katsina
# 92
# Processing record | katsina
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=katsina
# bluff
# 93
# Processing record | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bluff
# faya
# 94
# Processing record | faya
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=faya
# tiksi
# 95
# Processing record | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=tiksi
# thompson
# 96
# Processing record | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=thompson
# castro
# 97
# Processing record | castro
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=castro
# kropotkin
# 98
# Processing record | kropotkin
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kropotkin
# sitka
# 99
# Processing record | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=sitka
# clyde river
# 100
# Processing record | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=clyde river
# bredasdorp
# 101
# Processing record | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bredasdorp
# provideniya
# 102
# Processing record | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=provideniya
# basoko
# 103
# Processing record | basoko
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=basoko
# bethel
# 104
# Processing record | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bethel
# faanui
# 105
# Processing record | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=faanui
# tornio
# 106
# Processing record | tornio
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=tornio
# vaitupu
# 107
# Weather for vaitupu not found.
# cape town
# 108
# Processing record | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=cape town
# souillac
# 109
# Processing record | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=souillac
# tiznit
# 110
# Processing record | tiznit
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=tiznit
# osorno
# 111
# Processing record | osorno
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=osorno
# dolores
# 112
# Processing record | dolores
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=dolores
# longyearbyen
# 113
# Processing record | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=longyearbyen
# melfi
# 114
# Processing record | melfi
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=melfi
# tsihombe
# 115
# Weather for tsihombe not found.
# vestmannaeyjar
# 116
# Processing record | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=vestmannaeyjar
# tuktoyaktuk
# 117
# Processing record | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=tuktoyaktuk
# itarema
# 118
# Processing record | itarema
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=itarema
# buta
# 119
# Processing record | buta
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=buta
# saleaula
# 120
# Weather for saleaula not found.
# bolitoc
# 121
# Processing record | bolitoc
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bolitoc
# grenfell
# 122
# Processing record | grenfell
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=grenfell
# bom jesus
# 123
# Processing record | bom jesus
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bom jesus
# bilibino
# 124
# Processing record | bilibino
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bilibino
# bilma
# 125
# Processing record | bilma
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bilma
# cabo san lucas
# 126
# Processing record | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=cabo san lucas
# kahului
# 127
# Processing record | kahului
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kahului
# maun
# 128
# Processing record | maun
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=maun
# torbay
# 129
# Processing record | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=torbay
# olafsvik
# 130
# Weather for olafsvik not found.
# avarua
# 131
# Processing record | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=avarua
# boa vista
# 132
# Processing record | boa vista
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=boa vista
# bay saint louis
# 133
# Processing record | bay saint louis
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bay saint louis
# constitucion
# 134
# Processing record | constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=constitucion
# kem
# 135
# Processing record | kem
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kem
# consolacion del sur
# 136
# Processing record | consolacion del sur
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=consolacion del sur
# nizhneyansk
# 137
# Weather for nizhneyansk not found.
# tonder
# 138
# Processing record | tonder
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=tonder
# el alto
# 139
# Processing record | el alto
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=el alto
# elliot
# 140
# Processing record | elliot
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=elliot
# kineta
# 141
# Processing record | kineta
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kineta
# da nang
# 142
# Weather for da nang not found.
# guerrero negro
# 143
# Processing record | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=guerrero negro
# saint-pierre
# 144
# Processing record | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=saint-pierre
# dikson
# 145
# Processing record | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=dikson
# tamandare
# 146
# Processing record | tamandare
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=tamandare
# nizwa
# 147
# Processing record | nizwa
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=nizwa
# yellowknife
# 148
# Processing record | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=yellowknife
# cherskiy
# 149
# Processing record | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=cherskiy
# pasighat
# 150
# Processing record | pasighat
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=pasighat
# isangel
# 151
# Processing record | isangel
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=isangel
# upernavik
# 152
# Processing record | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=upernavik
# tasiilaq
# 153
# Processing record | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=tasiilaq
# plettenberg bay
# 154
# Processing record | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=plettenberg bay
# linchuan
# 155
# Weather for linchuan not found.
# samarai
# 156
# Processing record | samarai
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=samarai
# kuito
# 157
# Processing record | kuito
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kuito
# pisco
# 158
# Processing record | pisco
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=pisco
# prince albert
# 159
# Processing record | prince albert
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=prince albert
# omboue
# 160
# Processing record | omboue
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=omboue
# georgetown
# 161
# Processing record | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=georgetown
# marfino
# 162
# Processing record | marfino
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=marfino
# tabuk
# 163
# Processing record | tabuk
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=tabuk
# ahipara
# 164
# Processing record | ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ahipara
# nanortalik
# 165
# Processing record | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=nanortalik
# cape canaveral
# 166
# Processing record | cape canaveral
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=cape canaveral
# mahebourg
# 167
# Processing record | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=mahebourg
# mubi
# 168
# Processing record | mubi
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=mubi
# zhangye
# 169
# Processing record | zhangye
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=zhangye
# bandarbeyla
# 170
# Processing record | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bandarbeyla
# batemans bay
# 171
# Processing record | batemans bay
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=batemans bay
# saint anthony
# 172
# Processing record | saint anthony
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=saint anthony
# klaksvik
# 173
# Processing record | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=klaksvik
# upington
# 174
# Processing record | upington
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=upington
# atambua
# 175
# Processing record | atambua
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=atambua
# fairbanks
# 176
# Processing record | fairbanks
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=fairbanks
# bereda
# 177
# Processing record | bereda
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bereda
# ciudad del maiz
# 178
# Processing record | ciudad del maiz
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ciudad del maiz
# esperance
# 179
# Processing record | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=esperance
# lodja
# 180
# Processing record | lodja
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=lodja
# kavieng
# 181
# Processing record | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kavieng
# illoqqortoormiut
# 182
# Weather for illoqqortoormiut not found.
# sentyabrskiy
# 183
# Weather for sentyabrskiy not found.
# hare bay
# 184
# Processing record | hare bay
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=hare bay
# qaanaaq
# 185
# Processing record | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=qaanaaq
# bagdarin
# 186
# Processing record | bagdarin
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bagdarin
# kalabo
# 187
# Processing record | kalabo
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kalabo
# sibolga
# 188
# Processing record | sibolga
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=sibolga
# khandbari
# 189
# Processing record | khandbari
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=khandbari
# bull savanna
# 190
# Processing record | bull savanna
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bull savanna
# mayo
# 191
# Processing record | mayo
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=mayo
# aquiraz
# 192
# Processing record | aquiraz
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=aquiraz
# palmer
# 193
# Processing record | palmer
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=palmer
# lebu
# 194
# Processing record | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=lebu
# kapaa
# 195
# Processing record | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kapaa
# wanxian
# 196
# Processing record | wanxian
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=wanxian
# bela
# 197
# Processing record | bela
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bela
# nikolskoye
# 198
# Processing record | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=nikolskoye
# bogatoye
# 199
# Processing record | bogatoye
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bogatoye
# mackay
# 200
# Processing record | mackay
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=mackay
# sanming
# 201
# Processing record | sanming
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=sanming
# yulara
# 202
# Processing record | yulara
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=yulara
# buchanan
# 203
# Processing record | buchanan
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=buchanan
# dolbeau
# 204
# Weather for dolbeau not found.
# chunhuhub
# 205
# Processing record | chunhuhub
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=chunhuhub
# portobelo
# 206
# Processing record | portobelo
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=portobelo
# sangin
# 207
# Processing record | sangin
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=sangin
# alexandria
# 208
# Processing record | alexandria
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=alexandria
# sinnamary
# 209
# Processing record | sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=sinnamary
# airai
# 210
# Processing record | airai
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=airai
# sainte-thecle
# 211
# Processing record | sainte-thecle
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=sainte-thecle
# hofn
# 212
# Processing record | hofn
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=hofn
# gambela
# 213
# Processing record | gambela
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=gambela
# okha
# 214
# Processing record | okha
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=okha
# cayenne
# 215
# Processing record | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=cayenne
# mutsu
# 216
# Processing record | mutsu
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=mutsu
# sonoita
# 217
# Processing record | sonoita
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=sonoita
# codrington
# 218
# Processing record | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=codrington
# barentsburg
# 219
# Weather for barentsburg not found.
# deputatskiy
# 220
# Processing record | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=deputatskiy
# paoua
# 221
# Processing record | paoua
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=paoua
# nedumangad
# 222
# Processing record | nedumangad
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=nedumangad
# kaitangata
# 223
# Processing record | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kaitangata
# tautira
# 224
# Processing record | tautira
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=tautira
# lubango
# 225
# Processing record | lubango
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=lubango
# saint-philippe
# 226
# Processing record | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=saint-philippe
# tahta
# 227
# Weather for tahta not found.
# vostok
# 228
# Processing record | vostok
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=vostok
# bengkulu
# 229
# Weather for bengkulu not found.
# nigran
# 230
# Processing record | nigran
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=nigran
# gulu
# 231
# Processing record | gulu
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=gulu
# sfantu gheorghe
# 232
# Processing record | sfantu gheorghe
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=sfantu gheorghe
# ponta do sol
# 233
# Processing record | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ponta do sol
# karamea
# 234
# Weather for karamea not found.
# necochea
# 235
# Processing record | necochea
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=necochea
# borazjan
# 236
# Processing record | borazjan
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=borazjan
# gat
# 237
# Processing record | gat
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=gat
# bouca
# 238
# Processing record | bouca
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bouca
# ust-kuyga
# 239
# Processing record | ust-kuyga
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ust-kuyga
# la rioja
# 240
# Processing record | la rioja
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=la rioja
# mutsamudu
# 241
# Weather for mutsamudu not found.
# saint george
# 242
# Processing record | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=saint george
# ulladulla
# 243
# Processing record | ulladulla
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ulladulla
# moose factory
# 244
# Processing record | moose factory
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=moose factory
# port-gentil
# 245
# Processing record | port-gentil
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=port-gentil
# luanda
# 246
# Processing record | luanda
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=luanda
# santiago
# 247
# Processing record | santiago
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=santiago
# bunia
# 248
# Processing record | bunia
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bunia
# salalah
# 249
# Processing record | salalah
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=salalah
# dalbandin
# 250
# Processing record | dalbandin
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=dalbandin
# kruisfontein
# 251
# Processing record | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kruisfontein
# bambous virieux
# 252
# Processing record | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bambous virieux
# wenling
# 253
# Processing record | wenling
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=wenling
# vestby
# 254
# Processing record | vestby
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=vestby
# vryheid
# 255
# Processing record | vryheid
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=vryheid
# krasnoselkup
# 256
# Weather for krasnoselkup not found.
# cassilandia
# 257
# Processing record | cassilandia
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=cassilandia
# beckley
# 258
# Processing record | beckley
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=beckley
# billund
# 259
# Processing record | billund
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=billund
# chambas
# 260
# Processing record | chambas
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=chambas
# shaunavon
# 261
# Processing record | shaunavon
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=shaunavon
# hami
# 262
# Processing record | hami
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=hami
# storslett
# 263
# Processing record | storslett
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=storslett
# arzgir
# 264
# Processing record | arzgir
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=arzgir
# pocone
# 265
# Processing record | pocone
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=pocone
# aripuana
# 266
# Processing record | aripuana
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=aripuana
# alofi
# 267
# Processing record | alofi
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=alofi
# sao felix do xingu
# 268
# Processing record | sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=sao felix do xingu
# ribeira grande
# 269
# Processing record | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ribeira grande
# lavrentiya
# 270
# Processing record | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=lavrentiya
# bud
# 271
# Processing record | bud
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bud
# pevek
# 272
# Processing record | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=pevek
# bathsheba
# 273
# Processing record | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bathsheba
# mys shmidta
# 274
# Weather for mys shmidta not found.
# tommot
# 275
# Processing record | tommot
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=tommot
# mahaicony
# 276
# Weather for mahaicony not found.
# castries
# 277
# Processing record | castries
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=castries
# sungai padi
# 278
# Processing record | sungai padi
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=sungai padi
# cidreira
# 279
# Processing record | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=cidreira
# oktyabrskiy
# 280
# Processing record | oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=oktyabrskiy
# pahalgam
# 281
# Processing record | pahalgam
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=pahalgam
# berbera
# 282
# Weather for berbera not found.
# palabuhanratu
# 283
# Weather for palabuhanratu not found.
# pinos
# 284
# Processing record | pinos
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=pinos
# omsukchan
# 285
# Processing record | omsukchan
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=omsukchan
# abu dhabi
# 286
# Processing record | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=abu dhabi
# salinas
# 287
# Processing record | salinas
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=salinas
# avera
# 288
# Processing record | avera
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=avera
# libertador general san martin
# 289
# Processing record | libertador general san martin
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=libertador general san martin
# ust-bolsheretsk
# 290
# Weather for ust-bolsheretsk not found.
# chuy
# 291
# Processing record | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=chuy
# de aar
# 292
# Processing record | de aar
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=de aar
# yar-sale
# 293
# Processing record | yar-sale
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=yar-sale
# lahad datu
# 294
# Processing record | lahad datu
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=lahad datu
# abu samrah
# 295
# Processing record | abu samrah
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=abu samrah
# hithadhoo
# 296
# Processing record | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=hithadhoo
# burnie
# 297
# Processing record | burnie
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=burnie
# awjilah
# 298
# Processing record | awjilah
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=awjilah
# haverfordwest
# 299
# Processing record | haverfordwest
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=haverfordwest
# santa maria
# 300
# Processing record | santa maria
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=santa maria
# ambon
# 301
# Processing record | ambon
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ambon
# emerald
# 302
# Processing record | emerald
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=emerald
# vila franca do campo
# 303
# Processing record | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=vila franca do campo
# petropavlovsk-kamchatskiy
# 304
# Processing record | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=petropavlovsk-kamchatskiy
# ca mau
# 305
# Processing record | ca mau
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ca mau
# balkanabat
# 306
# Processing record | balkanabat
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=balkanabat
# oistins
# 307
# Processing record | oistins
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=oistins
# matara
# 308
# Processing record | matara
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=matara
# cabedelo
# 309
# Processing record | cabedelo
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=cabedelo
# ancud
# 310
# Processing record | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ancud
# san patricio
# 311
# Processing record | san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=san patricio
# dera bugti
# 312
# Processing record | dera bugti
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=dera bugti
# belmonte
# 313
# Processing record | belmonte
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=belmonte
# husavik
# 314
# Processing record | husavik
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=husavik
# port hedland
# 315
# Processing record | port hedland
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=port hedland
# biak
# 316
# Processing record | biak
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=biak
# vitim
# 317
# Processing record | vitim
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=vitim
# burns lake
# 318
# Processing record | burns lake
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=burns lake
# chernyshevskiy
# 319
# Processing record | chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=chernyshevskiy
# lata
# 320
# Processing record | lata
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=lata
# whitehorse
# 321
# Processing record | whitehorse
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=whitehorse
# phonhong
# 322
# Processing record | phonhong
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=phonhong
# santa
# 323
# Processing record | santa
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=santa
# farsund
# 324
# Processing record | farsund
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=farsund
# la ronge
# 325
# Processing record | la ronge
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=la ronge
# ambilobe
# 326
# Processing record | ambilobe
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ambilobe
# vidor
# 327
# Processing record | vidor
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=vidor
# broken hill
# 328
# Processing record | broken hill
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=broken hill
# metro
# 329
# Processing record | metro
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=metro
# lushunkou
# 330
# Weather for lushunkou not found.
# saint-augustin
# 331
# Processing record | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=saint-augustin
# nome
# 332
# Processing record | nome
# ...
# 521
# Processing record | belyy yar
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=belyy yar
# los llanos de aridane
# 522
# Processing record | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=los llanos de aridane
# syedove
# 523
# Processing record | syedove
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=syedove
# portlethen
# 524
# Processing record | portlethen
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=portlethen
# banes
# 525
# Processing record | banes
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=banes
# tezu
# 526
# Processing record | tezu
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=tezu
# nobres
# 527
# Processing record | nobres
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=nobres
# daloa
# 528
# Processing record | daloa
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=daloa
# panguna
# 529
# Processing record | panguna
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=panguna
# warqla
# 530
# Weather for warqla not found.
# yertsevo
# 531
# Processing record | yertsevo
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=yertsevo
# jurm
# 532
# Processing record | jurm
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=jurm
# mahajanga
# 533
# Processing record | mahajanga
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=mahajanga
# goma
# 534
# Processing record | goma
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=goma
# marystown
# 535
# Processing record | marystown
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=marystown
# qui nhon
# 536
# Weather for qui nhon not found.
# flinders
# 537
# Processing record | flinders
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=flinders
# samur
# 538
# Processing record | samur
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=samur
# sorland
# 539
# Processing record | sorland
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=sorland
# romny
# 540
# Processing record | romny
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=romny
# angra dos reis
# 541
# Processing record | angra dos reis
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=angra dos reis
# ibra
# 542
# Processing record | ibra
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ibra
# pahrump
# 543
# Processing record | pahrump
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=pahrump
# coihaique
# 544
# Processing record | coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=coihaique
# salinopolis
# 545
# Processing record | salinopolis
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=salinopolis
# kjollefjord
# 546
# Processing record | kjollefjord
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kjollefjord
# saint-joseph
# 547
# Processing record | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=saint-joseph
# kiunga
# 548
# Processing record | kiunga
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kiunga
# novikovo
# 549
# Processing record | novikovo
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=novikovo
# bedele
# 550
# Processing record | bedele
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bedele
# minna
# 551
# Processing record | minna
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=minna
# takoradi
# 552
# Processing record | takoradi
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=takoradi
# visegrad
# 553
# Processing record | visegrad
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=visegrad
# makakilo city
# 554
# Processing record | makakilo city
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=makakilo city
# vila velha
# 555
# Processing record | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=vila velha
# pokhara
# 556
# Processing record | pokhara
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=pokhara
# rabo de peixe
# 557
# Processing record | rabo de peixe
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=rabo de peixe
# margate
# 558
# Processing record | margate
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=margate
# khandyga
# 559
# Processing record | khandyga
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=khandyga
# lethem
# 560
# Processing record | lethem
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=lethem
# luoyang
# 561
# Processing record | luoyang
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=luoyang
# pudozh
# 562
# Processing record | pudozh
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=pudozh
# rungata
# 563
# Weather for rungata not found.
# shuangyang
# 564
# Processing record | shuangyang
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=shuangyang
# tignere
# 565
# Processing record | tignere
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=tignere
# carahue
# 566
# Processing record | carahue
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=carahue
# yanam
# 567
# Processing record | yanam
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=yanam
# santarem
# 568
# Weather for santarem not found.
# nacala
# 569
# Processing record | nacala
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=nacala
# alice springs
# 570
# Processing record | alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=alice springs
# tananger
# 571
# Processing record | tananger
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=tananger
# vila do maio
# 572
# Processing record | vila do maio
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=vila do maio
# port hardy
# 573
# Processing record | port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=port hardy
# bokspits
# 574
# Weather for bokspits not found.
# kannangad
# 575
# Processing record | kannangad
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kannangad
# ihosy
# 576
# Processing record | ihosy
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ihosy
# livadiya
# 577
# Processing record | livadiya
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=livadiya
# tazovskiy
# 578
# Processing record | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=tazovskiy
# riverton
# 579
# Processing record | riverton
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=riverton
# rania
# 580
# Processing record | rania
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=rania
# chagda
# 581
# Weather for chagda not found.
# autlan
# 582
# Weather for autlan not found.
# kodinsk
# 583
# Processing record | kodinsk
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kodinsk
# waw
# 584
# Weather for waw not found.
# broome
# 585
# Processing record | broome
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=broome
# hermiston
# 586
# Processing record | hermiston
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=hermiston
# progreso
# 587
# Processing record | progreso
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=progreso
# hobyo
# 588
# Processing record | hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=hobyo
# kant
# 589
# Processing record | kant
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kant
# mazatlan
# 590
# Processing record | mazatlan
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=mazatlan
# iqaluit
# 591
# Processing record | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=iqaluit
# rocha
# 592
# Processing record | rocha
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=rocha
# luderitz
# 593
# Processing record | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=luderitz
# mana
# 594
# Processing record | mana
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=mana
# candido mendes
# 595
# Processing record | candido mendes
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=candido mendes
# hakvik
# 596
# Weather for hakvik not found.
# mildura
# 597
# Processing record | mildura
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=mildura
# hokitika
# 598
# Processing record | hokitika
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=hokitika
# hualmay
# 599
# Processing record | hualmay
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=hualmay
# nelson bay
# 600
# Processing record | nelson bay
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=nelson bay
# albox
# 601
# Processing record | albox
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=albox
# cockburn harbour
# 602
# Weather for cockburn harbour not found.
# igrim
# 603
# Processing record | igrim
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=igrim
# beloha
# 604
# Processing record | beloha
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=beloha
# ust-nera
# 605
# Processing record | ust-nera
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=ust-nera
# udachnyy
# 606
# Processing record | udachnyy
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=udachnyy
# kadykchan
# 607
# Weather for kadykchan not found.
# gobabis
# 608
# Processing record | gobabis
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=gobabis
# labuhan
# 609
# Processing record | labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=labuhan
# marshfield
# 610
# Processing record | marshfield
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=marshfield
# bichura
# 611
# Processing record | bichura
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=bichura
# kazerun
# 612
# Processing record | kazerun
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kazerun
# grootfontein
# 613
# Processing record | grootfontein
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=grootfontein
# hambantota
# 614
# Processing record | hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=hambantota
# varhaug
# 615
# Processing record | varhaug
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=varhaug
# erenhot
# 616
# Processing record | erenhot
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=erenhot
# fort nelson
# 617
# Processing record | fort nelson
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=fort nelson
# dubai
# 618
# Processing record | dubai
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=dubai
# magistralnyy
# 619
# Processing record | magistralnyy
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=magistralnyy
# great falls
# 620
# Processing record | great falls
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=great falls
# kyshtovka
# 621
# Processing record | kyshtovka
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kyshtovka
# kenai
# 622
# Processing record | kenai
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kenai
# coracora
# 623
# Processing record | coracora
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=coracora
# tuatapere
# 624
# Processing record | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=tuatapere
# kolosovka
# 625
# Processing record | kolosovka
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=kolosovka
# dickson
# 626
# Processing record | dickson
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=dickson
# quelimane
# 627
# Processing record | quelimane
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=quelimane
# roald
# 628
# Processing record | roald
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=roald
# naze
# 629
# Processing record | naze
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=naze
# prince rupert
# 630
# Processing record | prince rupert
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=prince rupert
# tadine
# 631
# Processing record | tadine
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=tadine
# inhambane
# 632
# Processing record | inhambane
# http://api.openweathermap.org/data/2.5/weather?appid=f82e51275cfca026c27fe0b31e80d5fa&units=imperial&q=inhambane

# %% [markdown]
# ### Convert Raw Data to DataFrame

# %%
# Create dataframe with variables of interest
weatherpy_df = pd.DataFrame()
weatherpy_df["City"] = cities
weatherpy_df["Temperature (F)"] = temp
weatherpy_df["Latitude"] = lat
weatherpy_df["Longitude"] = lon
weatherpy_df["Humidity (%)"] = humidity
weatherpy_df["Cloudiness (%)"] = cloudiness
weatherpy_df["Wind Speed (MPH)"] = wind_speed

# Drop rows with null values / city not found
weatherpy_df_final = weatherpy_df[weatherpy_df != "Null"]
weatherpy_df_final.dropna(axis=0, how='any',inplace=True)
weatherpy_df_final.head()
# Out:
#          City Temperature (F) Latitude Longitude Humidity (%) Cloudiness (%)  \
# 0  sao filipe           81.05     14.9     -24.5           83              0
# 1     rikitea           72.95   -23.12   -134.97           71             95
# 2      carmen           78.46     7.36    125.71           94             75
# 3      hasaki           72.27    35.73    140.83           94             75
# 4     sikasso           80.33    11.32     -5.68           79             84
#
#   Wind Speed (MPH)
# 0            12.15
# 1              7.4
# 2             1.59
# 3              4.7
# 4             2.21

# %%
weatherpy_df_final.to_csv(r'CitiesData_NickBredahl.csv')

# %% [markdown]
# ### Plotting the Data

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weatherpy_df_final["Latitude"], weatherpy_df_final["Temperature (F)"], color="blue", edgecolors="black", s=30, alpha=0.75)
plt.title("City Latitude vs. Current Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weatherpy_df_final["Latitude"], weatherpy_df_final["Humidity (%)"], color="red", edgecolors="black", s=30, alpha=0.75)
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weatherpy_df_final["Latitude"], weatherpy_df_final["Cloudiness (%)"], color="green", edgecolors="black", s=30, alpha=0.75)
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weatherpy_df_final["Latitude"], weatherpy_df_final["Wind Speed (MPH)"], color="orange", edgecolors="black", s=30, alpha=0.75)
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.show()

# %% [markdown]
# ### Analysis - Observable Trends
